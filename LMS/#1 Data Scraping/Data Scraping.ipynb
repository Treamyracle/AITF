# %% [markdown]
# # Identifikasi dan Penjelasan Data Projek

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)

df1 = pd.read_csv("https://raw.githubusercontent.com/Treamyracle/AITF/refs/heads/main/%231%20Data%20Scraping/penjelasan_atribut_data.csv")
df1
# Out:
#             Nama Fitur         Tipe Data  \
# 0           Student ID       Kategorikal
# 1           First Name       Kategorikal
# 2            Last Name       Kategorikal
# 3               Gender       Kategorikal
# 4                  Age           Numerik
# 5            Ethnicity       Kategorikal
# 6   Parental Education       Kategorikal
# 7    Study Time Weekly           Numerik
# 8             Absences           Numerik
# 9             Tutoring  Biner (Ya/Tidak)
# 10    Parental Support       Kategorikal
# 11     Extracurricular  Biner (Ya/Tidak)
# 12              Sports  Biner (Ya/Tidak)
# 13               Music  Biner (Ya/Tidak)
# 14        Volunteering  Biner (Ya/Tidak)
# 15                 GPA           Numerik
# 16         Grade Class           Numerik
#
#                                                                                                      Alasan Pemilihan (Mengapa Penting?)
# ...

# %% [markdown]
# # Pengambilan Data Menggunakan Kaggle dan Tools Lain

# %%
# import kaggle
# import pandas as pd
# import os

# kaggle.api.authenticate()

# dataset_id = 'mirzayasirabdullah07/student-exam-scores-dataset'
# download_path = './data_siswa'

# print(f"Mengunduh dataset '{dataset_id}' ke folder '{download_path}'...")
# if not os.path.exists(download_path):
#     os.makedirs(download_path)

# kaggle.api.dataset_download_files(dataset_id, path=download_path, unzip=True)

# print("Pengunduhan dan ekstraksi selesai.")

# csv_file_path = os.path.join(download_path, 'Expanded_data_with_more_features.csv')
# df = pd.read_csv(csv_file_path)

# print("\nVerifikasi Hasil - 5 Baris Pertama Data:")
# print(df.head())

# print("\nInfo Data:")
# df.info()

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/Treamyracle/AITF/refs/heads/main/%231%20Data%20Scraping/student_exam_scores.csv")
df2.head()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %% [markdown]
# # Integrasi Data ke dalam Database atau Repository

# %%
# https://github.com/Treamyracle/AITF/blob/main/%231%20Data%20Scraping/student_exam_scores.csv
